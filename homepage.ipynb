# %% [markdown]
# # Homepage Statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Download the [statistics of the home page](https://kaust.libapps.com/libguides/stats.php) as CSV file.

# %%
homepage = pd.read_csv('../data/library_homepage_stats.csv', parse_dates=['Date'], index_col='Date')

# %%
print(homepage.head())
# Out:
#             Views
# Date
# 2023-04-01     55
# 2023-04-02    104
# 2023-04-03    129
# 2023-04-04    115
# 2023-04-05    100

# %%
homepage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 79 entries, 2023-04-01 to 2023-06-18
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Views   79 non-null     int64
# dtypes: int64(1)
# memory usage: 1.2 KB

# %%
homepage.plot(figsize=(6.5,2.5), title="Homepage views Q2 2023")
plt.savefig('../data/q2_2023_homepage.png', format="png")
plt.show()
